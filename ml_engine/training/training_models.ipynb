# %% [markdown]
# # 1. Load data

# %%
import pandas as pd

data = pd.read_csv('data/clean/applications.csv')
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25128 entries, 0 to 25127
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                25128 non-null  int64
#  1   car                               25128 non-null  int64
#  2   realty                            25128 non-null  int64
#  3   cnt_children                      25128 non-null  float64
#  4   income                            25128 non-null  float64
#  5   mobile_phone                      25128 non-null  int64
#  6   work_phone                        25128 non-null  int64
#  7   phone                             25128 non-null  int64
#  8   email                             25128 non-null  int64
#  9   cnt_fam_members                   25128 non-null  float64
#  10  age                               25128 non-null  float64
#  11  work_experience                   25128 non-null  float64
#  12  bad_debt                          25128 non-null  float64
#  13  good_debt                         25128 non-null  float64
#  14  gender_m                          25128 non-null  int64
#  15  income_type_pensioner             25128 non-null  int64
#  16  income_type_state_servant         25128 non-null  int64
#  17  income_type_student               25128 non-null  int64
#  18  income_type_working               25128 non-null  int64
#  19  education_type_higher_education   25128 non-null  int64
#  20  education_type_incomplete_higher  25128 non-null  int64
#  21  education_type_lower_secondary    25128 non-null  int64
#  22  education_type_secondary          25128 non-null  int64
#  23  fam_status_married                25128 non-null  int64
#  24  fam_status_separated              25128 non-null  int64
#  25  fam_status_single                 25128 non-null  int64
#  26  fam_status_widow                  25128 non-null  int64
#  27  housing_type_house                25128 non-null  int64
#  28  housing_type_municipal_apartment  25128 non-null  int64
#  29  housing_type_office_apartment     25128 non-null  int64
#  30  housing_type_rented_apartment     25128 non-null  int64
#  31  housing_type_with_parents         25128 non-null  int64
#  32  job_title_cleaning_staff          25128 non-null  int64
#  33  job_title_cooking_staff           25128 non-null  int64
#  34  job_title_core_staff              25128 non-null  int64
#  35  job_title_drivers                 25128 non-null  int64
#  36  job_title_high_skill_tech_staff   25128 non-null  int64
#  37  job_title_hr_staff                25128 non-null  int64
#  38  job_title_it_staff                25128 non-null  int64
#  39  job_title_laborers                25128 non-null  int64
#  40  job_title_low-skill_laborers      25128 non-null  int64
#  41  job_title_managers                25128 non-null  int64
#  42  job_title_medicine_staff          25128 non-null  int64
#  43  job_title_private_service_staff   25128 non-null  int64
#  44  job_title_realty_agents           25128 non-null  int64
#  45  job_title_sales_staff             25128 non-null  int64
#  46  job_title_secretaries             25128 non-null  int64
#  47  job_title_security_staff          25128 non-null  int64
#  48  job_title_waiters                 25128 non-null  int64
#  49  status                            25128 non-null  int64
# dtypes: float64(7), int64(43)
# memory usage: 9.6 MB

# %% [markdown]
# ## 1.2. Inspect outcome variable balance

# %%
data.iloc[:, -1].value_counts()
# Out:
# status
# 1    25007
# 0      121
# Name: count, dtype: int64

# %% [markdown]
# Due to class imbalance, we will use stratified sampling when splitting the data into training and test sets.

# %% [markdown]
# # 2. Split data into training and test sets

# %%
from sklearn.model_selection import train_test_split

X = data.iloc[:, 1:-1].values
y = data.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %% [markdown]
# ## 2.1. Use SMOTE to handle class imbalance

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=3)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # 3. Train models

# %% [markdown]
# ## 3.1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_classifier = LogisticRegression()
log_classifier.fit(X_train_resampled, y_train_resampled)
log_y_pred = log_classifier.predict(X_test)

# %% [markdown]
# ## 3.2. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_estimators=300, criterion='entropy', random_state=3)
rf_classifier.fit(X_train_resampled, y_train_resampled)
rf_y_pred = rf_classifier.predict(X_test)

# %% [markdown]
# ## 3.3. XGBoost Classifier

# %%
from xgboost import XGBClassifier

xgb_classifier = XGBClassifier(random_state=3)
xgb_classifier.fit(X_train_resampled, y_train_resampled)
xgb_y_pred = xgb_classifier.predict(X_test)

# %% [markdown]
# # 4. Review models performance

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

accuracy_log = cross_val_score(estimator=log_classifier, X=X_train_resampled, y=y_train_resampled, cv=10)
print("Logistic Regression CV Accuracy: %.2f%% +/- %.2f%%" % (accuracy_log.mean()*100, accuracy_log.std()*100))
print("Logistic Regression Accuracy:", accuracy_score(y_test, log_y_pred))
print(confusion_matrix(y_test, log_y_pred))
print('-'*10)
accuracy_rf = cross_val_score(estimator=rf_classifier, X=X_train_resampled, y=y_train_resampled, cv=10)
print("Random Forest CV Accuracy: %.2f%% +/- %.2f%%" % (accuracy_rf.mean()*100, accuracy_rf.std()*100))
print("Random Forest Accuracy:", accuracy_score(y_test, rf_y_pred))
print(confusion_matrix(y_test, rf_y_pred))
print('-'*10)
accuracy_xgb = cross_val_score(estimator=xgb_classifier, X=X_train_resampled, y=y_train_resampled, cv=10)
print("XGBoost CV Accuracy: %.2f%% +/- %.2f%%" % (accuracy_xgb.mean()*100, accuracy_xgb.std()*100))
print("XGBoost Accuracy:", accuracy_score(y_test, xgb_y_pred))
print(confusion_matrix(y_test, xgb_y_pred))
# Out:
# Logistic Regression CV Accuracy: 99.78% +/- 0.10%
# Logistic Regression Accuracy: 0.9974134500596896
# [[  23    1]
#  [  12 4990]]
# ----------
# Random Forest CV Accuracy: 99.89% +/- 0.33%
# Random Forest Accuracy: 0.9964186231595702
# [[   6   18]
#  [   0 5002]]
# ----------
# XGBoost CV Accuracy: 99.97% +/- 0.03%
# XGBoost Accuracy: 0.9994031038599284
# [[  24    0]
#  [   3 4999]]

# %% [markdown]
# # 5. Save the better model

# %%
xgb_classifier.save_model('model_a01.json')
